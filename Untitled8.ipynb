# %% [markdown]
# <a href="https://colab.research.google.com/github/namratameenanamrata12-a11y/DS_Exp/blob/main/Untitled8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def add(a, b):
  return a+b

# %%
x = 10
y = 20
res = add(x, y)
print(res)

# %%
def welcome():
  print("Welcome to pyhton lab")
welcome()

# %%
def square(n):
  return n*n
print(square(10))

# %%
def student(name, age = 19):
  print(name, age)
student("Namrata",20)

# %%
def student(name, age):
  print(name, age)
student("Namrata",19)

# %%
def student(name, age):
  print(name, age)
student(age = 20, name = "Namrata")

# %%
def add(*nums):
  total =0;
  for x in nums:
    total += x
  return (total)
res1 = add(10, 20)
print(res1)
res2 = add(1,20,30,40,50)
print(res2)

# %%
import numpy as np
n = int(input("How many numbers"))
numbers = []
for i in range(n):
  x = int(input("Enter a number"))
  numbers.append(x)

arr = np.array(numbers)
print("shape", arr.shape)
print("Dim",arr.ndim)
print("type",type(arr))
print("Array type",arr.dtype)

# %%
def create_Array(n):
  numbers = []
  for i in range(n):
    x = int(input("Enter a number"))
    numbers.append(x)
  return np.array(numbers)

n = int(input("How many numbers"))
arr = create_Array(n)
arr = np.array(numbers)
print("shape", arr.shape)
print("Dim",arr.ndim)
print("type",type(arr))
print("Array type",arr.dtype)

# %%
def cal(a,b):
  return a+b, a-b, a*b, a/b
add, sub, mul, div = cal(10,20)
print(add, sub, mul, div)

# %% [markdown]
# #  Reshaping

# %%
data = np.arange(1,13)
a = data.reshape(3,4)
b = data.reshape(4,3)
c = data.reshape(2,-1)
print(f'1-D data\n{data}')
print(f'2-D data\n{a}')
print(f'2-D data\n{b}')
print(f'2-D data\n{c}')

# %%
data =np.array([[1,2,3],[4,5,6]])
print("orig data",data.ndim)
flat1 = data.flatten()
print("Flatten flat1",flat1)
flat2 = data.ravel()
print("ravel flat2",flat2)

# %% [markdown]
# ## Combinig Arrays
# ## np.concatenate()
# ## np.vstack()
# ## np.hstack()

# %%
a = np.array([1,2,3])
b = np.array([4,5,6])
c = np.concatenate((a,b))
print("Concatenate \n",c)
print("vstack \n", np.vstack((a,b)))
print("Hstack \n", np.hstack((a,b)))

# %% [markdown]
# ## Vectorization

# %%
data = np.array([10,20,30,40,50])
res = []
for x in data:
  res.append(x*2)
print(np.array(res))

# %%
vec_res = data*2
print(vec_res)

# %%
a = np.array([10,20,30])
b = np.array([1,2,3])
print(a+b)
print(a-b)
print(a*b)
print(a/b)

# %%
marks = np.array([35,45,52,68,74,81,90])
passed = marks>=40
between = marks[(marks >= 50) & (marks <= 80)]
print(f'Marks for marks >= 40 {passed}')
print(f'Passing Marks:{marks[passed]}')
print(f'Marks between 50 and 80 {between}')

# %% [markdown]
# ## Broadcasting

# %%
arr = np.array([1,2,3])
res = arr+1
print (res)

# %%
a = np.array([1,2,3])
b = np.array([[1,2,3],[7,8,9]])
res = a+b
print(res)

# %%
a = np.array([12,24,35,45,60,70])
b = np.array(["Adult","Minor"])
res = np.where(a>18, "Adult", "Minor")
print(res)
